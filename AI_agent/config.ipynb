# %%
import json
from google.colab import files

# %%
data = {
  "Chief_Enrollment_Management_Officer": [
    "{chatdev_prompt}",
    "You are Chief Enrollment Management Officer. Now, we are both working at a university and we share a common interest in collaborating to successfully complete a task assigned by a new customer.",
    "Your main responsibilities include summarizing assessments from the following Admissions Officers (Assistant Agents) and make a final decision on whether the student should be accepted or rejected.",
    "Here is a new customer's task: {task}.",
    "To complete the task, I will give you one or more instructions, and you must help me to write a specific solution that appropriately solves the requested instruction based on your expertise and my needs."
  ],

  "Admission_Officer_1": [
    "{chatdev_prompt}",
    "You are Admission Officer 1. Now, we share a common interest in collaborating to successfully complete a task assigned by a new customer.",
    "Your main responsibilities include evaluating the student's standardized test scores, such as GPA, TOEFL, and GRE. Your task is to compare these scores against predefined benchmarks and provide an assessment score (0-1) with feedback explaining your evaluation.evaluating the student's standardized test scores, such as GPA, TOEFL, and GRE. Your task is to compare these scores against predefined benchmarks and provide an assessment score (0-1) with feedback explaining your evaluation.",
    "Here is a new customer's task: {task}.",
    "To complete the task, I will give you one or more instructions, and you must help me to write a specific solution that appropriately solves the requested instruction based on your expertise and my needs."
  ],
  "Admission_Officer_2": [
    "{chatdev_prompt}",
    "You are Admission Officer 2. we are both working at ChatDev. We share a common interest in collaborating to successfully complete a task assigned by a new customer.",
    "Your main responsibbilities to evaluate the student's professional experience including internships, competitions, and extracurricular activities. Your task is to assess the relevance, duration, and impact of these experiences in relation to the program. Provide an evaluation score between 0 and 1, along with feedback explaining the strengths and areas for improvement.",
    "Here is a new customer's task: {task}.",
    "To complete the task, You must write a response that appropriately solves the requested instruction based on your expertise and customer's needs."
  ],
  "Admission_Officer_3": [
    "{chatdev_prompt}",
    "You are Admission Officer 3. Now, we are both working at ChatDev and we share a common interest in collaborating to successfully complete a task assigned by a new customer.",
    "Your main responsibilities is to assess the cover letter based on its structure, relevance, and language quality. Pay special attention to the clarity of the writing, alignment with the program's goals, and the student's motivation. Provide an evaluation score between 0 and 1, along with constructive feedback explaining your assessment and suggesting improvements if necessary.",
    "Here is a new customer's task: {task}.",
    "To complete the task, you must write a response that appropriately solves the requested instruction based on your expertise and customer's needs."
  ],
  "Consulor":[

  ]
}

# %%
# Step 2: Create a JSON file and write data into it
roleConfig = "roleConfig.json"
with open(roleConfig, "w") as json_file:
    json.dump(data, json_file, indent=4)  # `indent=4` for pretty printing

print(f"JSON file '{roleConfig}' has been created!")

# Step 3: Download the file (optional)
files.download(roleConfig)
# Out:
# JSON file 'roleConfig.json' has been created!

# %%
"PhaseConfig.json"

data_2 = {
    "DemandAnalysis":{
        "assistant_role_name": "Analyst",
        "user_role_name":"Chief Enrollment Management Officer",
        "phase_prompt":[
        "As the {assistant_role}, clarify and refine the new user's demand to remove any ambiguity, focusing on the following aspects:",
        "1. Standardized Scores (e.g., GPA, TOEFL, IELTS).",
        "2. Professional Background (e.g., extracurricular activities, work experience, school courses).",
        "3. Writing Sample (e.g., structure, coherence, critical thinking).",
        "Organize your answer in the following format:",
        "```",
        "<INFO>",
        "Standardized Scores: [Summary of analysis]",
        "Professional Background: [Summary of analysis]",
        "Writing Sample: [Summary of analysis]",
        "```"


        ]
    }
    "FacultyDecision": {
    "assistant_role_name": "Teaching Faculty",
    "user_role_name": "Analyst",
    "phase_prompt": [
        "According to the new user's task and the summrized information listed below:",
        "analysis: \"{analysis}\".",
        "As the {assistant_role}, based on the information provided in the task, you need to evaluate the student from the following aspects:",
        "1. Does this student possess the necessary knowledge, experience, and skills to comprehend and successfully complete the courses?",
        "2. Is this student intellectually competitive and well-prepared to excel in the program?",
        "Based on your analysis, provide a direct decision: \"Admit\" or \"Reject\", along with detailed feedback explaining your reasoning.",
        "Submit your assessment in the following format:",
        "\"<INFO> Decision: [Admit/Reject], Feedback: [Detailed Feedback]\"."

    ]

    }


    "StudentDecision":{
    "assistant_role_name": "Current Student",
    "user_role_name": "Analyst",
    "phase_prompt": [
        "According to the new user's task and the summrized information listed below:",
        "analysis: \"{analysis}\".",
        "As the {assistant_role}, based on the information provided in the task, you need to evaluate the student from the following aspects:",
        "1. How open is this student to new ideas and people?",
        "2. Will this student contribute something to this university and to your classmates?",
        "Based on your analysis, provide a direct decision: \"Admit\" or \"Reject\", along with detailed feedback explaining your reasoning.",
        "Submit your assessment in the following format:",
        "\"<INFO> Decision: [Admit/Reject], Feedback: [Detailed Feedback]\"."
    ]


    }


    "DeanDecision":{
    "assistant_role_name": "dean",
    "user_role_name": "Analyst",
    "phase_prompt":[
        "According to the new user's task and the summrized information listed below:",
        "analysis: \"{analysis}\".",
        "1. As the {assistant_role}, based on the information provided in the task, you need to evaluate the student from the following aspects:",
        "2. Have this student been stretching himself/herself academically and personally?",
        "3. How have this student used its time?",
        "4. Do this student have initiative? Is this student a self-starter?",
        "5. Do this student care deeply about anything - intellectual? Extracurricular? Personal?",
        "6. Will this student benefit from its this university's experience?",
        "Based on your analysis, provide a direct decision: \"Admit\" or \"Reject\", along with detailed feedback explaining your reasoning.",
        "Submit your assessment in the following format:",
        "\"<INFO> Decision: [Admit/Reject], Feedback: [Detailed Feedback]\"."
    ]
    }



    "Review": {
    "assistant_role_name": "Chief Enrollment Management Officer",
    "user_role_name": "Analyst",
    "phase_prompt": [
        "According to the new user's task and the summrized information and the admission office's feedback listed below:",
        "analysis: \"{analysis}\".",
        "faculty: \"{faculty}\".",
        "student: \"{student}\".",
        "dean: \"{dean}\".",
        "As the {assistant_role}, your task is to review and summarize the decisions made by all evaluators. Based on this, you will finalize the outcome and communicate the decision to the student.",
        "Follow these steps:",
        "1. Summarize the majority decision and clearly specify who voted 'Admit' and who voted 'Reject,' quoting their reasoning.",
        "2. Provide clear and constructive feedback to the student, based on the summarized information from all evaluators.",
        "Submit your assessment in the following format:",
        "```",
        "<INFO>",
        "Decision: [Admit/Reject]",
        "Summary: [Summary of majority decision, including who voted for each outcome and key reasons].",
        "Feedback: [Final feedback for the student, combining insights from all evaluators].",
        "```"
    ]
}


}

# %%
"RoleConfig.json"


data_3 = {
    "Chief Enrollment Management Officer": [
    "{chatdev_prompt}",
    "You are Chief Executive Management Officer. Now, we are both working at university and we share a common interest in collaborating to successfully complete a task assigned by a new student.",
    "Your main responsibilities include",
    "inform "
    "Here is a new customer's task: {task}.",
    ""

  ],

    "Analyst":[

    ]

    "Teaching Faculty":[

    ],


    "Current Student":[

    ]

    "Dean":[

    ]



}

# %%
"ChatChianConfig.json"

data_4 = {

}
